# %% [markdown]
# # REG 평가 프로그램
# - Naive RAG vs Graph RAG

# %% [markdown]
# ## 설치와 준비
# - Graph RAG, Naive REG, RAGAS 평가 별로 Colab 세션 중단 및 새로 패키지 설치후 진행
# - 이유: Ragas, ChromaDB, langchain 버젼간 호환성 에러
# - Graph RAG 에서 Query 결과 파일로 저장
#  -> Naive RAG에서 Query 결과 파일로 저장
#  -> RAGAS 에서 이 두파일 읽어서 진행

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/aiffel/3.rag
# Out:
# /content/drive/MyDrive/aiffel/3.rag

# %%
# !pwd
# Out:
# /content/drive/MyDrive/aiffel/3.rag

# %%
from dotenv import load_dotenv
import os

load_dotenv("/content/drive/MyDrive/aiffel/env_keys/.env")

print("OPENAI_API_KEY loaded:", os.getenv("OPENAI_API_KEY") is not None)
print("NEO4J_URI loaded:", os.getenv("NEO4J_URI") is not None)
print("NEO4J_USERNAME loaded:", os.getenv("NEO4J_USERNAME") is not None)
print("NEO4J_PASSWORD loaded:", os.getenv("NEO4J_PASSWORD") is not None)
print("NEO4J_DATABASE loaded:", os.getenv("NEO4J_DATABASE") is not None)

NEO4J_URI      = os.getenv("NEO4J_URI")
NEO4J_USERNAME = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
NEO4J_DATABASE = os.getenv("NEO4J_DATABASE")
# Out:
# OPENAI_API_KEY loaded: True
# NEO4J_URI loaded: True
# NEO4J_USERNAME loaded: True
# NEO4J_PASSWORD loaded: True
# NEO4J_DATABASE loaded: True

# %%
# YOUR_API_KEY = ''

# %% [markdown]
# ### 설치:

# %%
# !pip install --upgrade langchain-core langchain-community langchain-neo4j
# !pip install --upgrade langchain langgraph openai langchain-openai langchain-experimental
# Out:
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (1.2.18)
# Collecting langchain-core
#   Downloading langchain_core-1.2.19-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-neo4j
#   Downloading langchain_neo4j-0.8.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (0.14.1)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.3-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.48)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.3)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain-neo4j)
#   Downloading langgraph-1.0.10-py3-none-any.whl.metadata (7.4 kB)
# Collecting neo4j-graphrag<2.0.0,>=1.12.0 (from langchain-neo4j)
#   Downloading neo4j_graphrag-1.14.0-py3-none-any.whl.metadata (19 kB)
# Collecting neo4j<7.0.0,>=5.25.0 (from langchain-neo4j)
#   Downloading neo4j-6.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Collecting langchain-text-splitters<2.0.0,>=1.1.1 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.1.0,>=1.0.2->langchain-neo4j) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.12/dist-packages (from neo4j<7.0.0,>=5.25.0->langchain-neo4j) (2025.2)
# Collecting fsspec<2025.0.0,>=2024.9.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting json-repair<0.45.0,>=0.44.1 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Collecting pypdf<7.0.0,>=6.0.0 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading pypdf-6.9.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j) (1.16.3)
# Collecting types-pyyaml<7.0.0,>=6.0.12.20240917 (from neo4j-graphrag<2.0.0,>=1.12.0->langchain-neo4j)
#   Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain-neo4j) (1.12.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading langchain_core-1.2.19-py3-none-any.whl (503 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.5/503.5 kB 10.1 MB/s eta 0:00:00
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 54.3 MB/s eta 0:00:00
# Downloading langchain_neo4j-0.8.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 3.4 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.3-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 52.8 MB/s eta 0:00:00
# Downloading langgraph-1.0.10-py3-none-any.whl (160 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.9/160.9 kB 13.7 MB/s eta 0:00:00
# Downloading neo4j-6.1.0-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 24.9 MB/s eta 0:00:00
# Downloading neo4j_graphrag-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 18.5 MB/s eta 0:00:00
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.2 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 15.8 MB/s eta 0:00:00
# Downloading json_repair-0.44.1-py3-none-any.whl (22 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 4.1 MB/s eta 0:00:00
# Downloading pypdf-6.9.1-py3-none-any.whl (333 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.7/333.7 kB 24.6 MB/s eta 0:00:00
# Downloading types_pyyaml-6.0.12.20250915-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: types-pyyaml, requests, pypdf, neo4j, mypy-extensions, marshmallow, json-repair, fsspec, typing-inspect, neo4j-graphrag, dataclasses-json, langchain-core, langchain-text-splitters, langchain-classic, langgraph, langchain-community, langchain-neo4j
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.18
#     Uninstalling langchain-core-1.2.18:
#       Successfully uninstalled langchain-core-1.2.18
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.1.1
#     Uninstalling langgraph-1.1.1:
#       Successfully uninstalled langgraph-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# langchain 1.2.12 requires langgraph<1.2.0,>=1.1.1, but you have langgraph 1.0.10 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed dataclasses-json-0.6.7 fsspec-2024.12.0 json-repair-0.44.1 langchain-classic-1.0.3 langchain-community-0.4.1 langchain-core-1.2.19 langchain-neo4j-0.8.0 langchain-text-splitters-1.1.1 langgraph-1.0.10 marshmallow-3.26.2 mypy-extensions-1.1.0 neo4j-6.1.0 neo4j-graphrag-1.14.0 pypdf-6.9.1 requests-2.32.5 types-pyyaml-6.0.12.20250915 typing-inspect-0.9.0
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.12)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.0.10)
# Collecting langgraph
#   Downloading langgraph-1.1.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.26.0)
# Collecting openai
#   Downloading openai-2.29.0-py3-none-any.whl.metadata (29 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.11-py3-none-any.whl.metadata (3.1 kB)
# Collecting langchain-experimental
#   Downloading langchain_experimental-0.4.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.19)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: langchain-community<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-experimental) (0.4.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.0.3)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (0.7.16)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community<1.0.0,>=0.4.0->langchain-experimental) (2.0.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.11.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (0.25.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (2.5.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community<1.0.0,>=0.4.0->langchain-experimental) (1.1.0)
# Downloading langgraph-1.1.2-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.5/167.5 kB 6.9 MB/s eta 0:00:00
# Downloading openai-2.29.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 25.3 MB/s eta 0:00:00
# Downloading langchain_openai-1.1.11-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.7/87.7 kB 6.7 MB/s eta 0:00:00
# Downloading langchain_experimental-0.4.1-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.1/210.1 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: openai, langchain-openai, langgraph, langchain-experimental
#   Attempting uninstall: openai
#     Found existing installation: openai 2.26.0
#     Uninstalling openai-2.26.0:
#       Successfully uninstalled openai-2.26.0
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.0.10
#     Uninstalling langgraph-1.0.10:
#       Successfully uninstalled langgraph-1.0.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-neo4j 0.8.0 requires langgraph<1.1.0,>=1.0.2, but you have langgraph 1.1.2 which is incompatible.
# Successfully installed langchain-experimental-0.4.1 langchain-openai-1.1.11 langgraph-1.1.2 openai-2.29.0

# %%
# !pip install langchain langchain-community langgraph neo4j openai

# %%
# !pip install langchain-openai

# %%
# !pip install langchain-experimental

# %%
# !pip install langchain-community langchain-classic

# %% [markdown]
# ### import

# %%
# from langchain_community.graphs import Neo4jGraph  # 또는 Memgraph
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_experimental.graph_transformers import LLMGraphTransformer
# from langchain_core.documents import Document
# from langchain_community.chains.graph_qa.cypher import GraphCypherQAChain

# from langgraph.graph import NetworkGraph  # 새 경로!
# from langchain_community.chains import GraphCypherQAChain
# from langchain_openai import ChatOpenAI
# import os

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

# %% [markdown]
# #### LLM 설정

# %%
from langchain_community.graphs import Neo4jGraph
from langchain_community.chains.graph_qa.cypher import GraphCypherQAChain # Changed import path
from langchain_openai import ChatOpenAI

# OpenAI
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# test
response = llm.invoke("안녕하세요!")
print(response.content)
# Out:
# 안녕하세요! 어떻게 도와드릴까요?

# %% [markdown]
# ### 의존성 모듈 설치

# %%
# !pip install -q pypdf pdf2image docx2txt pdfminer unstructured
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 43.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 55.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 48.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.8/453.8 kB 25.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.2/220.2 kB 14.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 4.9 MB/s eta 0:00:00
#   Building wheel for pdfminer (setup.py) ... done
#   Building wheel for langdetect (setup.py) ... done

# %% [markdown]
# ## Graph RAG

# %% [markdown]
# #### 클라우드 Neo4j(Aura) + Colab
# Neo4j 클라우드에 Colab에서 붙는 방식
#
# - Aura는 Neo4j를 클라우드에서 완전 관리형 서비스(DBaaS)로 제공하는 플랫폼
# <details>
# <summary>details</summary>
# 1. Aura가 하는 핵심 역할
# - Neo4j 그래프 데이터베이스를 “설치·운영” 걱정 없이 클라우드에서 바로 쓰게 해주는 서비스입니다.
#
# - 서버 인프라, 백업, 패치, 업그레이드, 모니터링 같은 운영을 Neo4j 측이 대신 맡고, 사용자는 Cypher로 쿼리만 날리면 됩니다.
#
# 2. 두 가지 주요 서비스 (AuraDB / AuraDS)
# - AuraDB: 트랜잭션 그래프 DB 서비스로, 애플리케이션에서 데이터 저장·조회·추천·경로 탐색 같은 그래프 쿼리를 수행할 때 사용합니다.
#
# - AuraDS: Graph Data Science(GDS)용으로, PageRank, 커뮤니티 탐지, 경로 최적화 등 그래프 알고리즘·예측 모델을 돌리기 위한 데이터 사이언스 워크로드에 맞춰진 서비스입니다.
# </details>
#
# - [Neo4j Aura 사이트](https://console.neo4j.io)에서 무료 인스턴스 생성
#
# - Aura 콘솔에서 제공하는(자동 생성):
#   - Bolt URL
#   - username
#   - password
# 를 복사.

# %% [markdown]
# #### 1. Neo4j를 python에서 활용 (그래프 DB 연결)

# %%
from langchain_neo4j import Neo4jGraph

graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD,
    database=NEO4J_DATABASE,
)

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer

transformer = LLMGraphTransformer(llm=llm)

# %% [markdown]
# #### 2. Demian.pdf 읽기

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Demian.pdf")
pages = loader.load_and_split()

# %%
pages[0]
# Out:
# Document(metadata={'producer': 'Adobe Acrobat Standard DC 19 Paper Capture Plug-in', 'creator': 'ScanFix(TM) Enhanced', 'creationdate': '2015-09-10T01:40:29+00:00', 'moddate': '2019-01-30T17:47:47+01:00', 'source': 'Demian.pdf', 'total_pages': 182, 'page': 0, 'page_label': '1'}, page_content='DEMIAN \n• \nDownloaded from https://www.holybooks.com')

# %%
print(pages[10].page_content)
# Out:
# TWO WOR.LDS
# Finally, out of sheer nervousness, I began to talk. I
# invented a long story of robbery, in which I featured as
# the hero. One night in the comer by the mill a friend
# and I ha.d stolen a whole sackful of apples, not just
# ordinary apples but pippins, golden pippins of the best
# kind at that. I was taking refuge in my story from the
# dangers of the moment and found no difficulty in invent­
# ing and relating it. In order not to dry up too soon and
# perhaps become involved in something worse, I gave full
# rein to my narrative powers. One of us, I reported, had
# always stood guard while the other sat in the tree and
# chucked the apples down, and the sack had got so heavy
# that in the end we had to open it and leave half behind,
# but we came back half an hour later and fetched them
# too.
# I hoped for some applause at the end of my story; I
# had warmed up to the narrative aJ: last, carried away by
# my own eloquence. The two smaller boys were silent,
# waiting, Lut Franz Kromer gave me a penetrating look
# through his narrow,-1 eyes. "Is that yarn true?" he
# asked in a menacing tone.
# "Yes," I said.
# "Really and truly?"
# "Yes, really and truly," I asserted defiantly while I
# choked inwardly with fear.
# "Can you swear to it?"
# I was very afraid but I said 'Yes' without hesitation.
# "Hand on your heart?"
# "Hand on my heart,"
# "Right then," he said and turned away.
# I thought this was all very satisfactory and I was glad
# 15
# Downloaded from https://www.holybooks.com

# %% [markdown]
# ### 3. PDF 로드 + 청크 만들기

# %% [markdown]
# ##### 토큰 준비

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2026.2.25)

# %%
import tiktoken
tokenizer = tiktoken.get_encoding("cl100k_base")

def tiktoken_len(text):
    tokens = tokenizer.encode(
        text
    )
    return len(tokens)

# %% [markdown]
# ##### 문서 청크 만들기

# %%
# !pip install -q langchain-text-splitters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100, length_function=tiktoken_len)
docs = text_splitter.split_documents(pages)
print(len(docs), docs[0].page_content[:200])
# Out:
# 182 DEMIAN
# •
# Downloaded from https://www.holybooks.com

# %% [markdown]
# #### 4. Neo4j Aura를 **벡터 스토어(Neo4jVector)**로 사용
# - Demian 청크들을 Neo4j Aura에 노드로 저장
# - 각 청크에 임베딩을 계산해서 벡터 인덱스까지 Aura 안에 생성
# - 따로 Chromadb는 불필요

# %%
from langchain_neo4j import Neo4jVector
from langchain_openai import OpenAIEmbeddings

url = NEO4J_URI
username = NEO4J_USERNAME
password = NEO4J_PASSWORD
database = NEO4J_DATABASE

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# vector_store = Neo4jVector.from_documents(
#     documents=docs,
#     embedding=embeddings,
#     url=url,
#     username=username,
#     password=password,
#     index_name="demian_index",      # 원하는 이름
# )

# 문서 임베딩 생성 + Aura에 바로 저장 (벡터 인덱스 생성)
vector_store = Neo4jVector.from_documents(
    documents=docs,          # 미리 만든 Document 리스트
    embedding=embeddings,
    url=url,
    username=username,
    password=password,
    database=database,
    index_name="demian_index",       # 원하는 Aura의 VECTOR INDEX 이름
    node_label="Chunk",
    text_node_property="text",
    embedding_node_property="embedding",
)

# %% [markdown]
# #### 5. RAG 체인 만들기 (Aura만 사용)

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.2.12
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.12/dist-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
# !pip install langchain-classic
# Out:
# Requirement already satisfied: langchain-classic in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.19 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (1.2.19)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (1.1.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (0.7.16)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.19->langchain-classic) (0.14.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.19->langchain-classic) (3.0.0)

# %%
# 리랭커 적용

from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.retrievers import ContextualCompressionRetriever
from langchain_classic.retrievers.document_compressors import LLMChainExtractor

# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# 1. 기본 retriever (fetch_k=8: 더 많이 가져와서 압축)
base_retriever = vector_store.as_retriever(search_kwargs={"k": 8})

# 2. LLM 기반 Compressor (리랭커)
compressor = LLMChainExtractor.from_llm(llm)

# 3. 압축 retriever (8개 → 관련성 높은 2개만 필터링)
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor,
    base_retriever=base_retriever,
)

# prompt = ChatPromptTemplate.from_template(
#     """당신은 친절한 AI 어시스턴트입니다.
# 다음 컨텍스트만 사용해서 질문에 답하세요.
# 모르면 모른다고 말하세요.

# 컨텍스트:
# {context}

prompt = ChatPromptTemplate.from_template(
    """당신은 신뢰성을 최우선으로 하는 AI 어시스턴트입니다.

다음 원칙을 반드시 지키세요.
1. 아래 컨텍스트에 **명시적으로 존재하는 정보**만 사용해서 답변하세요.
2. 컨텍스트에 없는 내용은 절대 추측하거나 상상해서 만들어내지 마세요.
3. 컨텍스트만으로는 충분한 답을 만들 수 없으면, "컨텍스트에 정보가 부족합니다"라고 분명히 말하세요.
4. 질문과 직접 관련되지 않은 세부 정보는 넣지 말고, 핵심 내용 위주로 간결하게 답변하세요.

컨텍스트:
{context}

질문: {input}"""
)

# 4. 문서 + LLM 결합 체인 (기존과 동일)
question_answer_chain = create_stuff_documents_chain(
    llm=llm,
    prompt=prompt,
    document_variable_name="context",
)

# 5. 리랭커 적용된 최종 RAG 체인
qa_chain = create_retrieval_chain(
    retriever=compression_retriever,  # 변경: 압축 retriever 사용
    combine_docs_chain=question_answer_chain,
)

# %%
# from langchain_openai import ChatOpenAI
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_classic.chains.combine_documents import create_stuff_documents_chain
# from langchain_classic.chains import create_retrieval_chain

# llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# retriever = vector_store.as_retriever(search_kwargs={"k": 2})  # 4 > 2

# prompt = ChatPromptTemplate.from_template(
#     """당신은 친절한 AI 어시스턴트입니다.
# 다음 컨텍스트만 사용해서 질문에 답하세요.
# 모르면 모른다고 말하세요.

# 컨텍스트:
# {context}

# 질문: {input}"""
# )

# # 1) 문서 + LLM을 결합하는 체인
# question_answer_chain = create_stuff_documents_chain(
#     llm=llm,
#     prompt=prompt,
#     document_variable_name="context",
# )

# # 2) Retriever와 합쳐서 최종 RAG 체인 구성
# qa_chain = create_retrieval_chain(
#     retriever=retriever,
#     combine_docs_chain=question_answer_chain,
# )

# %% [markdown]
# ### 6. Demian 내용에 질의 및 답변 저장

# %%
import json

# Demian 질문 5개 + GT (PDF 기반)
questions = [
    "데미안의 작가는 누구인가?",
    "데미안에서 주인공 이름은 무엇인가?",
    "데미안에서 주인공을 괴롭히는 소년 이름은?",
    "데미안에서 케인에 대한 데미안의 해석은 무엇인가?",
    "데미안에서 주인공이 사랑하는 여성 이름은?"
]
ground_truths = [
    "헤르만 헤세 (Hermann Hesse)",
    "에밀 싱클레어 (Emil Sinclair)",
    "프란츠 크로머 (Franz Kromer)",
    "케인은 강하고 용감한 사람으로, 표식은 보호와 구별의 표시이며 약자들은 두려워 왜곡했다",
    "베아트리체 (Beatrice, 또는 Frau Eva)"
]

# 1. qa_chain으로 데이터 자동 수집
data = {
    "question": questions,
    "contexts": [],
    "answer": [],
    "ground_truth": ground_truths
}

print("RAG 실행 중...")
for q in questions:
    result = qa_chain.invoke({"input": q})

    # contexts 추출: list[str]
    contexts = [doc.page_content for doc in result["context"]]
    answer = result["answer"]

    data["contexts"].append(contexts)
    data["answer"].append(answer)

    print(f"Q: {q}\nA: {answer[:100]}...\nContexts: {len(contexts)}개\n")

# 저장
with open("demian_rag_results.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("저장 완료: demian_rag_results.json")
# Out:
# RAG 실행 중...
# Q: 데미안의 작가는 누구인가?
# A: 데미안의 작가는 에밀 싱클레어입니다....
# Contexts: 1개
#
# Q: 데미안에서 주인공 이름은 무엇인가?
# A: 주인공 이름은 에밀 신클레어(Emil Sinclair)입니다....
# Contexts: 3개
#
# Q: 데미안에서 주인공을 괴롭히는 소년 이름은?
# A: 주인공을 괴롭히는 소년의 이름은 프란츠 크로머(Franz Kromer)입니다....
# Contexts: 5개
#
# Q: 데미안에서 케인에 대한 데미안의 해석은 무엇인가?
# A: 컨텍스트에 정보가 부족합니다....
# Contexts: 2개
#
# Q: 데미안에서 주인공이 사랑하는 여성 이름은?
# A: 주인공이 사랑하는 여성의 이름은 에바(Eva)입니다....
# Contexts: 2개
#
# 저장 완료: demian_rag_results.json

# %% [markdown]
# - 간단한 테스트

# %%
# query = "데미안에서 싱클레어가 처음으로 '표식(mark)'에 대해 깨닫는 장면이 뭐야?"
# result = qa_chain.invoke({"input": query})

# print("답변:\n", result["answer"])
# print("\n[출처 페이지들]")
# for doc in result["context"]:
#     print(doc.metadata.get("page", "?"), doc.page_content[:80], "...")
# Out:
# 답변:
#  싱클레어가 '표식(mark)'에 대해 처음으로 깨닫는 장면은 성경 수업 중에 목사가 가인과 아벨의 이야기를 하면서 가인의 표식에 대해 열정적으로 이야기할 때 발생합니다. 그 순간 싱클레어는 데미안의 시선을 느끼고, 목사의 말에 깊은 관심을 가지게 되며, 목사가 가르치는 내용이 옳지 않다는 것을 깨닫고 대안적인 해석이 가능하다는 것을 느낍니다. 이로 인해 싱클레어와 데미안 사이에 새로운 유대감이 형성됩니다.
#
# [출처 페이지들]
# 55 DJ:MIAN
# one day in the early morning class when the light was
# still burning in ...
# 53 DEMIAN
# with a feeling of nausea, I noticed Demian's expression.
# He had not thr ...
# 57 DEMIAN
# hoped that the pastor would not ask me any questions,
# he came to my res ...
# 107 DEMIAN
# I had anticipated. It wu ugly and somewhat wild
# looking, interrogative  ...

# %%
# 사용형식
# result = qa_chain.invoke({"input": "여기에 질문"})
# print(result["answer"])          # 최종 답변
# print(result["context"])         # 사용된 문서들

# %% [markdown]
# ## 기존 Naive REG

# %% [markdown]
# #### 1. 토큰 준비

# %%
# !pip install -U -q langchain langchain-openai
# !pip install -U -q langchain-community langchain-core
# !pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in /usr/local/lib/python3.12/dist-packages (1.1.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.13 in /usr/local/lib/python3.12/dist-packages (from langchain-text-splitters) (1.2.19)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.13->langchain-text-splitters) (2.5.0)

# %%
# !pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (0.12.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken) (2026.2.25)

# %%
# 위(Graph REG)와 중복
import tiktoken
tokenizer = tiktoken.get_encoding("cl100k_base")

def tiktoken_len(text):
    tokens = tokenizer.encode(
        text
    )
    return len(tokens)

# %% [markdown]
# #### 2. 문서 읽기

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 위(Graph REG)와 중복
loader = PyPDFLoader("Demian.pdf")
pages = loader.load_and_split()

n_text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100, length_function = tiktoken_len)
n_docs = n_text_splitter.split_documents(pages)

# %% [markdown]
# #### 3. TextEmbedding

# %%
# OpenAI embedding 사용
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings

# OpenAI 임베딩 모델 생성 (추천: text-embedding-3-small / large)
embedding_model = OpenAIEmbeddings(
    model="text-embedding-3-small"  # 또는 "text-embedding-3-large"
)

# %%
# test
text = "임베딩 테스트 문장입니다."
vector = embedding_model.embed_query(text)
print(len(vector), vector[:5])  # 벡터 길이, 일부만 출력
# Out:
# 1536 [-0.016765251755714417, 0.036890365183353424, 0.0302614513784647, -0.027083203196525574, -0.008450731635093689]

# %% [markdown]
# #### 4. VectorStore 사용 : ChromaDB

# %%
# !pip install chromadb
# Out:
# Requirement already satisfied: chromadb in /usr/local/lib/python3.12/dist-packages (1.5.5)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.41.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb) (4.26.0)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb) (26.0)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.32.5)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.4.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %%
# !pip install langchain-chroma
# Out:
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in /usr/local/lib/python3.12/dist-packages (from langchain-chroma) (1.5.5)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from langchain-chroma) (1.2.19)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from langchain-chroma) (2.0.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.12.3)
# Requirement already satisfied: pydantic-settings>=2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.1)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.41.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.4)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.2)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.78.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.24.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.7)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.7.16)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.14.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.30.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.32.5)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.7.1)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.73.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.40.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-proto==1.40.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.40.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.61b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.61b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.19.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.6.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2024.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.4.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.3.0)
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Installing collected packages: langchain-chroma
# Successfully installed langchain-chroma-1.1.0

# %%
# from langchain_community.vectorstores import Chroma
from langchain_chroma import Chroma

# %% [markdown]
# - Chroma에 임베딩

# %%
db = Chroma.from_documents(n_docs, embedding_model)

# %% [markdown]
# #### 5. Retriever 사용
#
# - Retriever는 사용자의 질문을 Embedding 모델을 통해 벡터로 변환한 뒤,
# VectorStore에 저장된 문서 벡터들과 비교하여
# 의미적으로 가장 유사한 문서(Chunk)를 찾아 반환하는 역할
#
# - 사용자 쿼리 → Retriever(ChromaDB 검색) → 관련 청크 반환 → LLM에 컨텍스트+쿼리 전달 → 답변 생성

# %%
# !pip install -U langchain langchain-classic
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.2.12)
# Requirement already satisfied: langchain-classic in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.2.19)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from langchain) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (1.1.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (0.7.16)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic) (2.0.48)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (4.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (1.0.8)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (0.3.11)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.1->langchain) (3.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2026.2.25)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.1->langchain) (1.12.2)

# %%
# from langchain_classic.chains import RetrievalQA
from langchain_classic.chains.retrieval_qa.base import RetrievalQA

# %%
from langchain_core.callbacks import StreamingStdOutCallbackHandler
from langchain_openai import ChatOpenAI

llm2 = ChatOpenAI(
    model="gpt-4o-mini",  # 또는 "gpt-4o"
    temperature=0.0,
    max_tokens=256,
    streaming=True,  # 스트리밍 활성화
    callbacks=[],  # Q 앞 문자 출력 제거 : [StreamingStdOutCallbackHandler()]  # 실시간 출력
)

# %%
# from langchain_core.prompts import PromptTemplate
# from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate


# # 커스텀 프롬프트 (한국어)
# prompt_template = """당신은 친절한 AI 어시스턴트입니다.
# 다음 컨텍스트만 사용해서 질문에 답하세요.
# 모르면 모른다고 말하세요.

prompt = ChatPromptTemplate.from_template(
    """당신은 신뢰성을 최우선으로 하는 AI 어시스턴트입니다.

다음 원칙을 반드시 지키세요.
1. 아래 컨텍스트에 **명시적으로 존재하는 정보**만 사용해서 답변하세요.
2. 컨텍스트에 없는 내용은 절대 추측하거나 상상해서 만들어내지 마세요.
3. 컨텍스트만으로는 충분한 답을 만들 수 없으면, "컨텍스트에 정보가 부족합니다"라고 분명히 말하세요.
4. 질문과 직접 관련되지 않은 세부 정보는 넣지 말고, 핵심 내용 위주로 간결하게 답변하세요.

컨텍스트:
{context}

질문: {input}"""
)

# qa = RetrievalQA.from_chain_type(llm2, chain_type="stuff",
#                                  retriever=db.as_retriever(
#                                      search_type="mmr",
#                                      search_kwargs={"k": 3, "fetch_k" : 10}),
#                                  return_source_documents=True)

qa = RetrievalQA.from_chain_type(
    llm=llm2,
    chain_type="stuff",
    retriever=db.as_retriever(
        search_type="mmr",
        search_kwargs={"k": 5, "fetch_k": 10}   # k: 3 > 5
    ),
    return_source_documents=True,
    chain_type_kwargs={"prompt": PROMPT}  # 커스텀 프롬프트 적용!
)

# %% [markdown]
# <details>
# <summary> 파라미터 설명 </summary>
#
# 🔹 chain_type="stuff"
#
# 검색된 문서(Chunk)를 그대로 하나의 Prompt에 모두 삽입하는 방식입니다.
# 구조가 단순하고 이해하기 쉬워,
# RAG 구조를 처음 학습하거나 프로토타입을 만들 때 적합합니다.
# 단점으로는 문서 수가 많아질 경우
# 토큰 사용량이 빠르게 증가할 수 있습니다.
# 실무에서는 초기 검증 단계에서는 stuff를,
# 문서 수가 많아지면 map_reduce나 refine 방식으로 확장합니다.
#
# 🔹 retriever
#
# VectorStore에서 어떤 문서를 검색할지 결정하는 검색 모듈입니다.
# 검색 전략과 파라미터 설정에 따라 LLM이 참고하는 정보의 범위와 품질이 달라집니다.
#
# 🔹 search_type="mmr"
#
# MMR(Maximal Marginal Relevance) 검색 방식을 사용합니다. 쿼리와의 유사도뿐만 아니라, 문서 간 중복을 줄여 다양한 문맥을 확보하는 Re-ranking 전략입니다. 실무 환경에서 단일 문서 편향을 줄이기 위해 자주 사용됩니다
#
# 🔹 search_kwargs={"k": 3, "fetch_k": 10}
# - fetch_k
# VectorStore에서 우선적으로 가져올 후보 문서 개수입니다. Re-ranking 이전 단계에서 사용됩니다.
# - k
# 최종적으로 LLM에게 전달할 문서(Chunk)의 개수입니다.
#
# 일반적으로 fetch_k > k 로 설정하여 후보 풀을 넉넉히 확보한 뒤, 품질 좋은 문서만 선별하는 방식을 사용합니다.
#
# 🔹 return_source_documents=True
#
# 답변 생성에 사용된 원문 문서(Chunk)를 함께 반환합니다. 이를 통해 답변의 출처를 사용자에게 표시하거나 검색 품질을 디버깅하고 RAG 성능을 평가할 수 있습니다. 실무 서비스에서는 거의 필수적으로 사용하는 옵션입니다.
# </detatils>

# %% [markdown]
# #### 6. Demian 내용에 질의 및 답변 저장

# %%
import json

# Demian 질문 5개
questions = [
    "데미안의 작가는 누구인가?",
    "데미안에서 주인공 이름은 무엇인가?",
    "데미안에서 주인공을 괴롭히는 소년 이름은?",
    "데미안에서 케인에 대한 데미안의 해석은 무엇인가?",
    "데미안에서 주인공이 사랑하는 여성 이름은?"
]
ground_truths = [
    "헤르만 헤세 (Hermann Hesse)",
    "에밀 싱클레어 (Emil Sinclair)",
    "프란츠 크로머 (Franz Kromer)",
    "케인은 강하고 용감한 사람으로, 표식은 보호와 구별의 표시이며 약자들은 두려워 왜곡했다",
    "베아트리체 (Beatrice, 또는 Frau Eva)"
]

# 데이터 수집 (위 Graph REG 구조와 호환)
data = {
    "question": questions,
    "contexts": [],
    "answer": [],
    "ground_truth": ground_truths
}

print("RAG 실행 중...")
for i, q in enumerate(questions):
    result = qa(q)  # 간단한 호출

    # 기존 result 구조: result["result"], result["source_documents"]
    answer = result["result"]
    contexts = [doc.page_content for doc in result["source_documents"]]

    data["contexts"].append(contexts)
    data["answer"].append(answer)

    print(f"Q{i+1}: {q}")
    print(f"A: {answer[:100]}...")
    print(f"Contexts: {len(contexts)}개\n")

print("=== 평가 데이터 수집 완료 ===")
print("data 딕셔너리:", list(data.keys()))

# 저장
with open("demian_naive_rag_results.json", "w", encoding="utf-8") as f:
    json.dump(data, f, ensure_ascii=False, indent=2)

print("저장 완료: demian_naive_rag_results.json")
# Out:
# RAG 실행 중...
# Q1: 데미안의 작가는 누구인가?
# A: 컨텍스트에 정보가 부족합니다....
# Contexts: 5개
#
# Q2: 데미안에서 주인공 이름은 무엇인가?
# A: 주인공의 이름은 싱클레어(Sinclair)입니다....
# Contexts: 5개
#
# Q3: 데미안에서 주인공을 괴롭히는 소년 이름은?
# A: 주인공을 괴롭히는 소년의 이름은 프란츠 크로머(Franz Kromer)입니다....
# Contexts: 5개
#
# Q4: 데미안에서 케인에 대한 데미안의 해석은 무엇인가?
# A: 데미안에서 케인에 대한 해석은 케인이 다른 사람들에게 두려움을 주는 '표지'를 가지고 있었다는 것입니다. 데미안은 케인이 실제로 이마에 어떤 특별한 표식이 있었던 것이 아니라, 그...
# Contexts: 5개
#
# Q5: 데미안에서 주인공이 사랑하는 여성 이름은?
# A: 주인공이 사랑하는 여성의 이름은 에바(Eva)입니다....
# Contexts: 5개
#
# === 평가 데이터 수집 완료 ===
# data 딕셔너리: ['question', 'contexts', 'answer', 'ground_truth']
# 저장 완료: demian_naive_rag_results.json

# %% [markdown]
# RAG를 사용하지 않은 llm 호출도 시도해보세요!

# %%
# from langchain_openai import ChatOpenAI

# # llm3 = ChatGoogleGenerativeAI(model = "gemini-1.5-flash", temperature=0.0)
# llm3 = ChatOpenAI(
#     model="gpt-4o-mini",  # 또는 "gpt-4o"
#     temperature=0.0
# )

# request = llm2.invoke("how demian looks like")
# display(Markdown(request.content))

# %% [markdown]
# # RAGAS 평가

# %% [markdown]
# ### 평가준비

# %% [markdown]
# #### 답변 파일 읽기

# %%
# 답변 로드해서 Dataset 만들기
from datasets import Dataset
import json

with open("demian_rag_results.json", "r", encoding="utf-8") as f:
    loaded_data = json.load(f)

GraphREG_dataset = Dataset.from_dict(loaded_data)
print(GraphREG_dataset)

print("-" * 50)

with open("demian_naive_rag_results.json", "r", encoding="utf-8") as f:
    loaded_data = json.load(f)

NaiveREG_dataset = Dataset.from_dict(loaded_data)
print(NaiveREG_dataset)
# Out:
# Dataset({
#     features: ['question', 'contexts', 'answer', 'ground_truth'],
#     num_rows: 5
# })
# --------------------------------------------------
# Dataset({
#     features: ['question', 'contexts', 'answer', 'ground_truth'],
#     num_rows: 5
# })

# %%
# test
from pprint import pprint

one_row_dataset = GraphREG_dataset.select([0])
pprint(one_row_dataset[0])

print("-" * 50)

one_row_dataset = NaiveREG_dataset.select([0])
pprint(one_row_dataset[0])
# Out:
# {'answer': '데미안의 작가는 에밀 싱클레어입니다.',
#  'contexts': ['The novel D,mian was fint publiahed under the paeuc:IO!lym Emil '
#               'Sinclair, the name or a friend or the poet Novalil whom Hme 10 '
#               'much admired.'],
#  'ground_truth': '헤르만 헤세 (Hermann Hesse)',
#  'question': '데미안의 작가는 누구인가?'}
# --------------------------------------------------
# {'answer': '컨텍스트에 정보가 부족합니다.',
#  'contexts': ['DJ:MIAN \n'
#               'one day in the early morning class when the light was \n'
#               'still burning in the schoolroom. Our scripture teacher, a \n'
#               'pastor, had embarked on the story of Cain and Abel. I \n'
#               'was still sleepy and only listening with half an ear. All \n'
#               'at once the pastor began to hold forth about the mark \n'
#               'of Cain in loud and excited tones. At that moment I \n'
#               'became aware of a stirring-up inside me, a kind of \n'
#               "challenge, and, looking up, I saw Demian's face turning \n"
#               'round towards me from the front desks with that clear, \n'
#               'eloquent glance of his which might be expressing scorn \n'
#               'or gravity, you could not be sure which. He merely \n'
#               'looked at me for a moment, and suddenly I gave the \n'
#               "pastor's words my fullest attention, listened to him \n"
#               'speaking of Cain and his mark, and felt deep within me \n'
#               'the knowledge that the thing was not as he was teaching \n'
#               'it, but that there was an alternative interpretation and \n'
#               'that criticism of his view was justifiable. \n'
#               'A fresh bond was forged between Demian and myself \n'
#               'in that moment. And, strangely enough, hardly was I \n'
#               'aware of this spiritual closeness between us when I saw \n'
#               'it tranJlated as if by magic into physical closeness. I '
#               'had"\' \n'
#               'no idea whether he had managed to arrange it in that \n'
#               'way or whether it was fate-I firmly believed in strokes \n'
#               'of fate at that time-but a few days later Demian had \n'
#               'suddenly changed his place in the scripture class and sat \n'
#               'cHrectly in front of me. I can recall how I enjoyed \n'
#               'smelling the fresh, delicate perfume of soap from his \n'
#               'neck in the midst of the miserable workhouse atmos\xad\n'
#               'phere of the over-crowded schoolroom I And again, some \n'
#               'days later he had changed places again and was sitting \n'
#               'next to me where he stayed all through winter and spring, \n'
#               '58 \n'
#               'Downloaded from https://www.holybooks.com',
#               'DEMIAN \n'
#               'Then I remembered my watch. It was a silver watch but \n'
#               "it did not go. I just wore it 'like that.' It came to me from \n"
#               'my grandmother. I quiqc.ly drew it out. \n'
#               '"Kromer," I said, "You mustn\'t tell; it would be a \n'
#               "beastly thing to do. Look, I'll give you my watch; un\xad\n"
#               "luckily it's the only thing I have, but you can have it. \n"
#               'It\'s made of silver," I added nervously. "It\'s good work\xad\n'
#               "manship and it's only got some slight defect which can \n"
#               'easily be put right." \n'
#               'He smiled and took the watch in his large hand. I \n'
#               'looked at that hand and felt how rough and hostile it \n'
#               'was towards me and how it was trying to tighten its grip \n'
#               'on my life and peace of mind. \n'
#               '"It\'s silver," I repeated nervously. \n'
#               '"I don\'t give a damn for your silver and your old \n'
#               'watch I" he said with withering scorn. "Get it repaired \n'
#               'yourself I " \n'
#               '"But Franz," I exclaimed, trembling with fear lest he \n'
#               'walk off. "Just wait a moment! Take the watch! It \n'
#               "really is made of silver, honestly. And I haven't got \n"
#               'anything else." \n'
#               'He gave me a cold, scornful look. \n'
#               '"Well, you know who I\'m going to see. Or I might \n'
#               'even inform the police. The sergeant is a friend of \n'
#               'mine." \n'
#               'He turned as if to go. I held him back by his coat \n'
#               'sleeve. He must not go. I would much rather die than \n'
#               'have to suffer what would happen if he went off like \n'
#               'that. \n'
#               '"Franz," I implored, hot with emotion, "don\'t do any\xad\n'
#               'thing stupid I It as a joke, isn\'t it?" \n'
#               '16 \n'
#               'Downloaded from https://www.holybooks.com',
#               'DltMIAN \n'
#               'might lead me. But it was not easy and every day I \n'
#               "rejected it' a&esh. \n"
#               'Perhaps, as I often thought, I was mad; perhaps merely \n'
#               'different from other men. But I too could do what others \n'
#               "'1:lid; with a little effort and industry I could read Plato, \n"
#               'solve problems of trigonometry or understand chemical \n'
#               'analyses. There was only one thing I could not do-wrest \n'
#               'from myself the darkly hidden goal and obtain some sort \n'
#               'of picture-as others did who knew exactly that they \n'
#               'wanted to become teachers, judges, doctors or artists-of \n'
#               'how long the process would take and what hopes such a \n'
#               "fut';lre could hold out. But this I could not do. Perhaps \n"
#               'it would be possible one day, but could I feel assured of \n'
#               'that? Perhaps I should have to seek continually for \n'
#               'years and then become nothing; I would attain some \n'
#               'goal but it would be an evil, dangerous and fearful one. \n'
#               'All I wanted was to try and realize whatever was in \n'
#               'me. Why was that so difficult? \n'
#               'I made frequent attempts to paint the forceful dream\xad\n'
#               'apparition but always without success. If I had been \n'
#               'successful I would have sent the picture to Demian. \n'
#               'Where was he? I did not know. I only knew that our \n'
#               'fates were bound up together. When would I see him \n'
#               'again? \n'
#               'The pleasant tranquillity of the weeks and months of \n'
#               'the Beatrice period had long receded. At that time1 had \n'
#               'thought I had reached an island and found peace at last. \n'
#               'But it was always like that-practically no situation \n'
#               'seemed agreeable. I was no sooner cheered by a dream \n'
#               'thz.p it immediately faded. It was no use moaning for it I \n'
#               'I n~~ had within me a furnace of unsatisfied · aavinp, \n'
#               '106 \n'
#               'Downloaded from https://www.holybooks.com',
#               'DEMIAN \n'
#               'guide and leader was not far away from me. \n'
#               'A great town could be seen in the clouds and out of \n'
#               'it poured millions of men who spread in hosts over vast \n'
#               'landscapes. In their midst strode a mighty, godlike form \n'
#               'wi~ shining stars in her hair, as huge as a mountain \n'
#               'but having the features of Frau Eva. The ranks of men \n'
#               'were swallowed up into her as into a gigantic cave and \n'
#               'vanished from sight. The goddess crouched on the \n'
#               "ground, the 'sign' shone on her brow. She seemed to \n"
#               'be in the grip of a dream. She closed her eyes and her \n'
#               'great countenance was twisted in pain. Suddenly she \n'
#               'called out, and from her forehead sprang stars, many \n'
#               'thousands of them which leaped in graceful curves across \n'
#               'the dark heavens. \n'
#               'One of the stars shot straight towards me with a clear, \n'
#               'ringing sound; it seemed to be seeking me out. Then it \n'
#               'burst with a roar into a thousand sparks, bore me aloft \n'
#               'and cast me down to the ground again; the world was \n'
#               'shattered above me with a thunderous roar ... \n'
#               'They found me near the poplar covered with earth \n'
#               'and with many wounds. \n'
#               'I lay in a cellar, shells roared over me. I lay in a \n'
#               'waggon and staggered across devastated fields. Mostly I \n'
#               'slept and was unconscious. But the more deeply I slept, \n'
#               'the more strongly I felt that someone was drawing me \n'
#               'onwards, that I was held in tow by some force that had \n'
#               'mastery over me. \n'
#               'I lay in a stable on straw; it was dark. Someone had \n'
#               'trodden on my hand. But my inner self still pressed \n'
#               'forward and I was drawn on more forcefully than ever. \n'
#               'Again I lay on a waggon and later on a stretcher or a \n'
#               '18a \n'
#               'Downloaded from https://www.holybooks.com',
#               'DEMIAN \n'
#               'and the atmosphere painful and strained-presenu, \n'
#               'Christmas wishes, Bible reading and illuminated tree-\xad\n'
#               'everything seemed out of place. The gingerbread smelt \n'
#               'sweet and evoked a host of more agreeable memories. \n'
#               'The Christmas tree with its fragrance reminded me of \n'
#               'things as they had been in former days. I longed for \n'
#               'Christmas Eve and the holidays to be over. \n'
#               'It was like this the whole winter. Only quite recently \n'
#               'I had been solemnly warned by the masten at school and \n'
#               'threatened with expulsion. It could not go on much \n'
#               'longer. At least as far as I was concerned. \n'
#               'I had one special grudge against Max Demian, whom \n'
#               'I had not seen now for some time. I had written to him \n'
#               'twice at the beginning of my school term in St. -- but \n'
#               'had received no reply; so I had not called on him during \n'
#               'the holidays. \n'
#               'In the same park where during the autumn I had met \n'
#               'Alfons Beck, in the early spring when the hedges were \n'
#               'beginning to show green, I encountered a girl to whom \n'
#               'I felt an immediate attraction. I had gone out for a \n'
#               'solitary walk, my head filled with unsavoury thoughts \n'
#               'and worries, for my health had not been good and, to \n'
#               'make matters worse, I wai. in perpetual financial difficul\xad\n'
#               'ties. I owed sums of money to various friends and had \n'
#               'to keep producing presents by way of bribes, and in \n'
#               'several shops I had allowed bills for cigars and suchlike \n'
#               'to mount up. Not that these anxieties went very deep\xad\n'
#               'if my existence was to come to an end very soon and I \n'
#               'drowned myself or was transferred to a reformatory, these \n'
#               'trifling matters would never arise. But I lived face to \n'
#               'face with these ugly facts and they made me wretched. \n'
#               '86 \n'
#               'Downloaded from https://www.holybooks.com'],
#  'ground_truth': '헤르만 헤세 (Hermann Hesse)',
#  'question': '데미안의 작가는 누구인가?'}

# %% [markdown]
# #### 환경 준비

# %%
# [실습 환경 준비]
# Ragas 및 LangChain 관련 최신 패키지를 설치합니다.
# !pip install -qU ragas langchain langchain-openai langchain-community chromadb tiktoken nest_asyncio pandas

# !pip install -qU \
#   ragas==0.1.14 \
#   langchain==0.2.14 \
#   langchain-openai==0.1.23 \
#   langchain-community==0.2.12 \
#   chromadb==1.5.5 \
#   tiktoken==0.7.0 \
#   nest_asyncio==1.6.0 \
#   pandas==2.2.2 \
#   requests==2.32.4 \
#   fsspec==2024.12.0

# !pip install -qU \
  "numpy<2.0" \
  ragas==0.1.14 \
  langchain==0.2.14 \
  langchain-openai==0.1.23 \
  langchain-community==0.2.12 \
  chromadb==1.5.5 \
  tiktoken==0.7.0 \
  nest_asyncio==1.6.0 \
  pandas==2.2.2 \
  requests==2.32.4 \
  fsspec==2024.12.0

# !pip check
# Out:
# ipython 7.34.0 requires jedi, which is not installed.
# langchain-experimental 0.4.1 has requirement langchain-community<1.0.0,>=0.4.0, but you have langchain-community 0.2.12.
# langchain-experimental 0.4.1 has requirement langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.2.43.
# langchain-neo4j 0.8.0 has requirement langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.2.43.
# langchain-neo4j 0.8.0 has requirement langgraph<1.1.0,>=1.0.2, but you have langgraph 1.1.2.
# unstructured 0.21.5 has requirement requests<3.0.0,>=2.32.5, but you have requests 2.32.4.
# neo4j-graphrag 1.14.0 has requirement numpy<3.0.0,>=2.0.0; python_version >= "3.9" and python_version < "3.13", but you have numpy 1.26.4.
# neo4j-graphrag 1.14.0 has requirement tenacity<10.0.0,>=9.1.2, but you have tenacity 8.5.0.
# langchain-classic 1.0.3 has requirement langchain-core<2.0.0,>=1.2.19, but you have langchain-core 0.2.43.
# langchain-classic 1.0.3 has requirement langchain-text-splitters<2.0.0,>=1.1.1, but you have langchain-text-splitters 0.2.4.
# langchain-chroma 1.1.0 has requirement langchain-core<2.0.0,>=1.1.3, but you have langchain-core 0.2.43.
# opencv-python-headless 4.13.0.92 has requirement numpy>=2; python_version >= "3.9", but you have numpy 1.26.4.
# jax 0.7.2 has requirement numpy>=2.0, but you have numpy 1.26.4.
# tobler 0.13.0 has requirement numpy>=2.0, but you have numpy 1.26.4.
# xarray-einstats 0.10.0 has requirement numpy>=2.0, but you have numpy 1.26.4.
# opentelemetry-exporter-gcp-logging 1.11.0a0 has requirement opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.40.0.
# rasterio 1.5.0 has requirement numpy>=2, but you have numpy 1.26.4.
# opencv-python 4.13.0.92 has requirement numpy>=2; python_version >= "3.9", but you have numpy 1.26.4.
# opencv-contrib-python 4.13.0.92 has requirement numpy>=2; python_version >= "3.9", but you have numpy 1.26.4.
# opentelemetry-exporter-otlp-proto-http 1.38.0 has requirement opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.40.0.
# opentelemetry-exporter-otlp-proto-http 1.38.0 has requirement opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.40.0.
# opentelemetry-exporter-otlp-proto-http 1.38.0 has requirement opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.40.0.
# google-adk 1.26.0 has requirement opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.40.0.
# google-adk 1.26.0 has requirement opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.40.0.
# google-adk 1.26.0 has requirement tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0.
# jaxlib 0.7.2 has requirement numpy>=2.0, but you have numpy 1.26.4.
# shap 0.51.0 has requirement numpy>=2, but you have numpy 1.26.4.
# gcsfs 2025.3.0 has requirement fsspec==2025.3.0, but you have fsspec 2024.12.0.
# langgraph-prebuilt 1.0.8 has requirement langchain-core>=1.0.0, but you have langchain-core 0.2.43.
# pytensor 2.38.2 has requirement numpy>=2.0, but you have numpy 1.26.4.

# %%
# RAGAS는 평가 속도를 높이기 위해 내부적으로 asyncio.gather를 사용해 수백 개의 API를 동시에 비동기 호출합니다.
# Jupyter/Colab 환경은 이미 자체적인 비동기 이벤트 루프를 돌리고 있어서 충돌이 발생합니다.
# nest_asyncio는 이 충돌을 막아주어 Colab에서도 RAGAS가 병렬 처리를 할 수 있게 해줍니다.
import nest_asyncio
nest_asyncio.apply()

# %%
import os
from google.colab import userdata

# os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")

# %%
# 판사(Judge) 역할을 할 LLM과 임베딩 세팅
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

evaluator_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
evaluator_embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# %% [markdown]
# #### Metics 정의 및 평가

# %%
import ragas
from ragas import metrics

print(metrics.__all__)
# 또는 dir(metrics)로 어떤 이름이 있는지 확인
print(dir(metrics))
# Out:
# ['AnswerCorrectness', 'answer_correctness', 'Faithfulness', 'faithfulness', 'FaithulnesswithHHEM', 'AnswerSimilarity', 'answer_similarity', 'ContextPrecision', 'context_precision', 'ContextUtilization', 'context_utilization', 'ContextRecall', 'context_recall', 'AspectCritique', 'AnswerRelevancy', 'answer_relevancy', 'ContextEntityRecall', 'context_entity_recall', 'SummarizationScore', 'summarization_score']
# ['AnswerCorrectness', 'AnswerRelevancy', 'AnswerSimilarity', 'AspectCritique', 'ContextEntityRecall', 'ContextPrecision', 'ContextRecall', 'ContextUtilization', 'Faithfulness', 'FaithulnesswithHHEM', 'SummarizationScore', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_answer_correctness', '_answer_relevance', '_answer_similarity', '_context_entities_recall', '_context_precision', '_context_recall', '_faithfulness', '_summarization', 'answer_correctness', 'answer_relevancy', 'answer_similarity', 'base', 'context_entity_recall', 'context_precision', 'context_recall', 'context_utilization', 'critique', 'faithfulness', 'summarization_score']

# %%
from ragas import evaluate
from ragas.metrics import (
    Faithfulness,
    AnswerRelevancy,
    ContextRecall,
    ContextPrecision,
)

metrics = [
    Faithfulness(),
    AnswerRelevancy(),
    ContextRecall(),
    ContextPrecision(),
]

# 결과 평가
graph_result = evaluate(
    dataset=GraphREG_dataset,
    metrics=metrics,
    llm=evaluator_llm,
    embeddings=evaluator_embeddings,
    raise_exceptions=False # API 에러 발생 시 중단하지 않음
)

naive_result  = evaluate(
    dataset=NaiveREG_dataset,
    metrics=metrics,
    llm=evaluator_llm,
    embeddings=evaluator_embeddings,
    raise_exceptions=False # API 에러 발생 시 중단하지 않음
)
# Out:
# Evaluating:   0%|          | 0/20 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/20 [00:00<?, ?it/s]

# %%
print(naive_result)
# Out:
# {'faithfulness': 0.4000, 'answer_relevancy': 0.1293, 'context_recall': 0.4000, 'context_precision': 0.2400}

# %% [markdown]
# ### 평가 결과

# %% [markdown]
# #### 평균 점수 비교

# %%
# pd.set_option('display.max_colwidth', None)
# df_result = result.to_pandas()
# display(df_result[['faithfulness', 'answer_relevancy', 'context_precision', 'context_recall']])

# 메트릭별 비교 (class 이름 기준)
metric_keys = ["faithfulness", "answer_relevancy", "context_precision", "context_recall"]

print("\n=== 메트릭별 평균 점수 비교 ===")
for key in metric_keys:
    g_score = graph_result[key]
    n_score = naive_result[key]
    print(f"{key:18s} | GraphREG: {g_score:.3f} | NaiveREG: {n_score:.3f}")
# Out:
# === 메트릭별 평균 점수 비교 ===
# faithfulness       | GraphREG: 0.400 | NaiveREG: 0.400
# answer_relevancy   | GraphREG: 0.160 | NaiveREG: 0.129
# context_precision  | GraphREG: 0.300 | NaiveREG: 0.240
# context_recall     | GraphREG: 0.400 | NaiveREG: 0.400

# %% [markdown]
# 첫 테스트 결과:
# ```
# === 메트릭별 평균 점수 비교 ===
# faithfulness       | GraphREG: 0.200 | NaiveREG: 0.200
# answer_relevancy   | GraphREG: 0.105 | NaiveREG: 0.031
# context_precision  | GraphREG: 0.000 | NaiveREG: 0.267
# context_recall     | GraphREG: 0.400 | NaiveREG: 0.200
# ```
#
# 이번 테스트 결과:
# ```
# === 메트릭별 평균 점수 비교 ===
# faithfulness       | GraphREG: 0.400 | NaiveREG: 0.400
# answer_relevancy   | GraphREG: 0.160 | NaiveREG: 0.129
# context_precision  | GraphREG: 0.300 | NaiveREG: 0.240
# context_recall     | GraphREG: 0.400 | NaiveREG: 0.400
# ```
#
# GraphREG, NaiveREG : 청크 사이즈 변경, retriever k 값 변경(GraphREG: 리랭커), 프롬프트 변경 등을 진행 후 평가 점수가 높아졌으나 부족한 수준

# %% [markdown]
# <details>
# <summary>각 지표가 의미하는 것</summary>
#
# - faithfulness (충실도)
#   - 생성 답변이 실제로 제공된 컨텍스트에 얼마나 거짓 없이 근거를 두고 있는지 보는 지표.
#
#   - 0.2라는 값은 둘 다 “컨텍스트에 없는 말을 하거나 애매한 부분이 꽤 있다”는 뜻으로, 두 모델이 충실도 측면에서는 거의 동급이라는 의미다.
#
# - answer_relevancy (답변 관련성)
#   - 질문 의도에 답변이 얼마나 직접적으로 관련 있는지 평가.
# ```
# GraphREG: 0.105
# NaiveREG: 0.031
# ```
#   - 절대값 자체는 낮지만, GraphREG가 NaiveREG보다 질문과 더 맞는 방향으로 대답하는 경향이 있다.
#    예: 질문이 “표식에 대해 깨닫는 장면”인데, GraphREG는 그 장면 근처를 설명하고, Naive는 소설 전체 분위기만 말하는 식.
#
# - context_precision (컨텍스트 정밀도)
#   - 검색된 컨텍스트들 중 “실제 답변에 유용한 것들 비율”을 보는 지표.
# ```
# GraphREG: 0.000
# NaiveREG: 0.267
# ```
#   - 여기서는 오히려 NaiveREG가 더 적절한 문단을 골라온 것처럼 평가된 상황이다.
#   - GraphREG의 precision=0.0은, RAGAS 기준으로 “답변에 쓰인 핵심 정보가 검색 컨텍스트에 잘 안 보인다” 혹은 “잡소스가 많고, 핵심 문단이 위에 안 떠 있다”라는 해석이 가능하다.
#
# - context_recall (컨텍스트 재현율)
# 질문에 답하는 데 필요한 정보가 검색된 컨텍스트 안에 충분히 들어 있는지 보는 지표.
# ```
# GraphREG: 0.400
# NaiveREG: 0.200
# ```
#   - GraphREG는 답변에 필요한 정보는 더 많이 포함하지만, 그중에서 정말 필요한 부분만 깔끔하게 골라 쓰지는 못해 precision이 0이 되는 그림이라고 볼 수 있다.
#   - 반대로 NaiveREG는 적지만 꽤 관련 있는 chunk만 가져와서 recall은 낮고 precision은 높은 패턴.
#
# - 요약해서 해석
#   - 둘 다 faithfulness=0.2로 “데미안 PDF 컨텍스트에 충실한 답변을 꾸준히 내는 수준까지는 아직 부족”하다.
#
#   - GraphREG
#
#     - 질문 관련성(답변 내용)이 더 좋음: answer_relevancy ↑
#
#     - 필요한 정보는 더 많이 가져오지만(context_recall ↑), 거기서 실제 답변에 쓴 “핵심 근거 chunk”가 RAGAS 기준으로 잘 매핑되지 않아 precision=0.
#
#   - NaiveREG
#
#     - 질문 관련성은 떨어지지만(answer_relevancy 낮음),
#
#     - 적은 양의 컨텍스트 중에서 “질문과 직접 관련 있는 문단”을 상대적으로 잘 뽑은 것으로 평가(context_precision > 0).
#
#   - 그래서 현재 세팅에서는:
#
#     -“사용자 질문에 더 잘 맞는 답을 주냐?” → GraphREG가 우세.
#
#     - “적은 컨텍스트로도 딱 맞는 문단을 뽑았냐?” → NaiveREG가 더 나아 보임.
#
#   - 실무적으로는
#
#   1. GraphREG의 리트리버를 좀 더 aggressive하게 정리해서 불필요한 chunk 줄이기(precision ↑),
#
#   2. NaiveREG는 질문 의도에 맞는 답변을 더 직접적으로 생성하도록 프롬프트/LLM 튜닝(AnswerRelevancy ↑)
# 방향으로 튜닝하면 두 시스템 모두 개선 여지가 있다.
#
# </details>

# %% [markdown]
# #### 평가 상세

# %%
from pprint import pprint

# 1) 결과를 dict/list 형태로 변환 (버전에 따라 약간 다를 수 있음)
graph_df = graph_result.to_pandas()
naive_df = naive_result.to_pandas()

# graph_df / naive_df에는 각 row가 하나의 질문에 해당하고,
# 컬럼 이름은 'question', 'answer', 'faithfulness', 'answer_relevancy', ... 형태라고 가정.
print(graph_df.columns)
print(naive_df.columns)

# 2) 질문 수 확인 (둘이 동일해야 함)
num_rows = len(GraphREG_dataset)
assert num_rows == len(NaiveREG_dataset)

# 3) 각 질문에 대한 상세 정보 출력
metric_cols = ["faithfulness", "answer_relevancy", "context_precision", "context_recall"]

for i in range(num_rows):
    q = GraphREG_dataset[i]["question"]          # 두 dataset 모두 question 동일하다고 가정
    g_ans = GraphREG_dataset[i]["answer"]
    n_ans = NaiveREG_dataset[i]["answer"]

    print("=" * 80)
    print(f"[Q{i+1}] 질문: {q}\n")

    print("[GraphREG 답변]")
    print(g_ans, "\n")

    print("[NaiveREG 답변]")
    print(n_ans, "\n")

    # 점수는 graph_df / naive_df에서 같은 인덱스 row에서 꺼냄
    print("[평가 점수]")
    for col in metric_cols:
        if col in graph_df.columns and col in naive_df.columns:
            g_score = graph_df.iloc[i][col]
            n_score = naive_df.iloc[i][col]
            print(f"  - {col}: GraphREG={g_score:.3f}, NaiveREG={n_score:.3f}")
    print()  # blank line
# Out:
# Index(['question', 'contexts', 'answer', 'ground_truth', 'faithfulness',
#        'answer_relevancy', 'context_recall', 'context_precision'],
#       dtype='object')
# Index(['question', 'contexts', 'answer', 'ground_truth', 'faithfulness',
#        'answer_relevancy', 'context_recall', 'context_precision'],
#       dtype='object')
# ================================================================================
# [Q1] 질문: 데미안의 작가는 누구인가?
#
# [GraphREG 답변]
# 데미안의 작가는 에밀 싱클레어입니다.
#
# [NaiveREG 답변]
# 컨텍스트에 정보가 부족합니다.
#
# [평가 점수]
#   - faithfulness: GraphREG=0.000, NaiveREG=0.000
#   - answer_relevancy: GraphREG=0.000, NaiveREG=0.000
#   - context_precision: GraphREG=0.000, NaiveREG=0.000
#   - context_recall: GraphREG=0.000, NaiveREG=0.000
#
# ================================================================================
# [Q2] 질문: 데미안에서 주인공 이름은 무엇인가?
#
# [GraphREG 답변]
# 주인공 이름은 에밀 신클레어(Emil Sinclair)입니다.
#
# [NaiveREG 답변]
# 주인공의 이름은 싱클레어(Sinclair)입니다.
#
# [평가 점수]
#   - faithfulness: GraphREG=1.000, NaiveREG=1.000
#   - answer_relevancy: GraphREG=0.210, NaiveREG=0.246
#   - context_precision: GraphREG=0.000, NaiveREG=0.000
#   - context_recall: GraphREG=0.000, NaiveREG=1.000
#
# ================================================================================
# [Q3] 질문: 데미안에서 주인공을 괴롭히는 소년 이름은?
#
# [GraphREG 답변]
# 주인공을 괴롭히는 소년의 이름은 프란츠 크로머(Franz Kromer)입니다.
#
# [NaiveREG 답변]
# 주인공을 괴롭히는 소년의 이름은 프란츠 크로머(Franz Kromer)입니다.
#
# [평가 점수]
#   - faithfulness: GraphREG=1.000, NaiveREG=1.000
#   - answer_relevancy: GraphREG=0.208, NaiveREG=0.179
#   - context_precision: GraphREG=0.500, NaiveREG=0.000
#   - context_recall: GraphREG=1.000, NaiveREG=1.000
#
# ================================================================================
# [Q4] 질문: 데미안에서 케인에 대한 데미안의 해석은 무엇인가?
#
# [GraphREG 답변]
# 컨텍스트에 정보가 부족합니다.
#
# [NaiveREG 답변]
# 데미안에서 케인에 대한 해석은 케인이 다른 사람들에게 두려움을 주는 '표지'를 가지고 있었다는 것입니다. 데미안은 케인이 실제로 이마에 어떤 특별한 표식이 있었던 것이 아니라, 그의 눈에 더 많은 지혜와 자제력이 있었기 때문에 사람들을 압도하고 두려움을 불러일으켰다고 설명합니다. 이 '표지'는 사람들이 케인과 그의 자녀들을 두려워하게 만든 요소로, 그들은 이 표지를 이상하게 해석하여 케인과 그의 후손들을 기이한 존재로 여겼습니다.
#
# [평가 점수]
#   - faithfulness: GraphREG=0.000, NaiveREG=0.000
#   - answer_relevancy: GraphREG=0.000, NaiveREG=0.000
#   - context_precision: GraphREG=0.500, NaiveREG=1.000
#   - context_recall: GraphREG=0.000, NaiveREG=0.000
#
# ================================================================================
# [Q5] 질문: 데미안에서 주인공이 사랑하는 여성 이름은?
#
# [GraphREG 답변]
# 주인공이 사랑하는 여성의 이름은 에바(Eva)입니다.
#
# [NaiveREG 답변]
# 주인공이 사랑하는 여성의 이름은 에바(Eva)입니다.
#
# [평가 점수]
#   - faithfulness: GraphREG=0.000, NaiveREG=0.000
#   - answer_relevancy: GraphREG=0.383, NaiveREG=0.222
#   - context_precision: GraphREG=0.500, NaiveREG=0.200
#   - context_recall: GraphREG=1.000, NaiveREG=0.000

# %% [markdown]
# ### 회고
#
# - 이번 프로젝트를 하면서 느낀점, 배운점 :
#   - Naive REG, Graph REG에 대해 점더 이해를 높이고, RAGAS 에 대해 새로 배웠습니다.
#   - OpenAI를 사용해서 답변이 실제적으로 나와 좋았습니다.
# - 이번 프로젝트에서 잘 했다고 생각이 드는 점 :
#   - 평가 점수를 높이고자 여러번 시도를 했지만 만족스러운 점수가 나오지는 못했습니다.
# - 이번 프로젝트에서 느낀 문제점. :
#   - 필요한 패키지 버전 충돌로 환경 설정에 많은 시간을 썼습니다.
#   - 파일을 3개로 나누어 진행했으면 더 나았을것 같습니다.
# - 다음에는 이렇게 해야겠다 생각한 점. :
#   - 평가지표를 높이기위한 다양한 시도
